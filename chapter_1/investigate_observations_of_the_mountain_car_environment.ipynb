# %% [markdown]
# # Investigate observations of the `MountainCar-v0` environment
#
# In the last exercise, you set up the `MountainCar-v0` environment and visualized the initial state of the environment. It looked like this.
#
# ![mountain_car.jpg](attachment:mountain_car.jpg)
#
# However, this is the human view of the environment. The agent's view of the environment is usually very different from the human view. In the `MountainCar-v0` environment, the agent is the tiny car in the valley.
#
# In this exercise, we will find out how the agent observes the `MountainCar-v0` environment.
#
# In the video lesson, we investigated the agent's view of the `CartPole-v0` environment and found that the observation is of type `Box(4,)`, meaning an array of four floating point numbers. Now it is time to do the same thing for the `MountainCar-v0` environment.
#
# Ready? Here's what I have already done for you.
#
# 1. I have written the code to setup the `MountainCar-v0` environment, bring it to its initial state, and store the initial observation of the agent in the variable `observation`.
#
# Here's what you need to do.
#
# 1. Print out the observation space of the `MountainCar-v0` environment.
# 2. Based on the value of the observation space, predict the number of elements in `observation` and their types.
# 3. Print out `observation`. Check if your prediction was correct.

# %%
# Run this cell first
import gym

env = gym.make("MountainCar-v0")
observation = env.reset()

# %%
# Print out the observation space

# %% [markdown]
# ## Fill in the blanks
#
# 1. Based on the value of the observation space, I predict that `observation` is an array containing ____ elements.
# 2. I predict that the elements in `observation` are of type ____.

# %%
# Print out observation and check if your prediction was correct

# %% [markdown]
# If your prediction was correct, then congratulations! You can read the observation space correctly and therefore, can see the environment with the eyes of the agent!
#
# If you are feeling curious, why not go to the [Wiki page for MountainCar-v0 on gym's GitHub repository](https://github.com/openai/gym/wiki/MountainCar-v0) and find out what the elements in `observation` actually mean?
